# %%
#exception handling
try:
    num = int(input("Enter a number: "))
    print("You entered:", num)
except ValueError:
    print("Please enter a valid integer!")
# Out:
# Enter a number: 2
# You entered: 2

# %%
try:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))
    result = a / b
    print("Result:", result)
except ZeroDivisionError:
    print("Cannot divide by zero!")
except ValueError:
    print("Enter valid numbers only!")
# Out:
# Enter first number: 4
# Enter second number: 6
# Result: 0.6666666666666666

# %%
my_list = [10, 20, 30, 40, 50]
try:
    index = int(input("Enter index: "))
    if 0 <= index < len(my_list):
        print("Element:", my_list[index])
    else:
        print("Index out of range!")
except ValueError:
    print("Please enter a valid number!")
# Out:
# Enter index: 10
# Index out of range!

# %%
try:
    f=open("cleaning steps sample.txt","r")
    print(f.read())
except FileNotFoundError:
    print("file not found!")
# Out:
# file not found!

# %%
class LoginError(Exception):
    pass
correct_user = "admin"
correct_pass = "1234"
attempts = 0
while attempts < 3:
    u = input("Username: ")
    p = input("Password: ")
    if u == correct_user and p == correct_pass:
        print("Login successful")
        break
    else:
        attempts += 1
        print("Wrong credentials")
if attempts == 3:
    raise LoginError("Too many attempts!")
# Out:
# Username: admin
# Password: 1234
# Login successful

# %%
class InsufficientBalanceError(Exception):
    pass
balance = 500
try:
    amount = int(input("Enter amount to withdraw: "))
    if amount > balance:
        raise InsufficientBalanceError("Not enough balance!")
    else:
        balance -= amount
        print("Withdrawal successful")
        print("Remaining balance:", balance)
except InsufficientBalanceError as e:
    print("", e)
except ValueError:
    print("Enter a valid amount!")
# Out:
# Enter amount to withdraw: 100
# Withdrawal successful
# Remaining balance: 400

# %%
class AgeError(Exception):
    pass
age = int(input("Enter age: "))
if age < 0 or age > 120:
    raise AgeError("Invalid age")
else:
    print("Valid age")
# Out:
# Enter age: 21
# Valid age

# %%
try:
    a = int(input("Enter a number: "))
    b = int(input("Enter another number: "))
    result = a / b
    print("Result:", result)
except ValueError:
    print("Enter numbers only!")
except ZeroDivisionError:
    print("Cannot divide by zero!")
except Exception:
    print("Some error occurred!")
# Out:
# Enter a number: 2
# Enter another number: a
# Enter numbers only!

# %%
file = None
try:
    file = open("cleaning steps sample.txt", "r")
    content = file.read()
    print(content)
except FileNotFoundError:
    print("File not found!")
finally:
    if file:
        file.close()
        print("File closed")
# Out:
# File not found!

# %%
#file handling
file = open("users.txt", "w")
for i in range(10):
    name = input("Enter username: ")
    file.write(name + "\n")
file.close()
print("Names stored successfully")
# Out:
# Enter username: swany
# Enter username: rushiba
# Enter username: anusiya
# Enter username: harshitha
# Enter username: nandhini
# Enter username: jancy
# Enter username: arun
# Enter username: rose
# Enter username: cemal
# Enter username: blue
# Names stored successfully

# %%
file = open("Cleaning steps sample.txt", "r")
for line in file:
    if "python" in line:
        print(line)
file.close()

# %%
file = open("Cleaning steps sample.txt", "r")
data = file.read()
print("Lines:", len(data.splitlines()))
print("Words:", len(data.split()))
print("Characters:", len(data))
file.close()
# Out:
# Lines: 125
# Words: 314
# Characters: 1905

# %%
file = open("Cleaning steps sample.txt", "a")
text = input("Enter text: ")
file.write(text + "\n")
file.close()
print("Data appended")
# Out:
# Enter text: datascience
# Data appended

# %%
from datetime import datetime
file = open("Cleaning steps sample.txt", "a")
time = datetime.now()
file.write(str(time) + " - Login Success\n")
file.close()
print("Log added")
# Out:
# Log added

# %%
source = open("Cleaning steps sample.txt", "r")
data = source.read()
target = open("Cleaning steps sample.txt", "w")
target.write(data)
source.close()
target.close()
print("File copied")
# Out:
# File copied

# %%
file = open("Cleaning steps sample.txt", "r")
lines = file.readlines()
unique = set(lines)
newfile = open("cleaning.txt", "w")
newfile.writelines(unique)
file.close()
newfile.close()
print("Duplicates removed")
# Out:
# Duplicates removed

# %%
file = open("file = open("Cleaning steps sample.txt", "r")
for line in file:
    data = line.split(",")
    print("Name:", data[0])
    print("Age:", data[1])
file.close().txt", "w")
name = input("Enter name: ")
mark1 = int(input("Enter mark1: "))
mark2 = int(input("Enter mark2: "))
total = mark1 + mark2
file.write(name + " " + str(total))
file.close()
print("Total:", total)
# Out:
# Enter name: data
# Enter mark1: 20
# Enter mark2: 40
# Total: 60

# %%
file = open("Cleaning steps sample.txt", "r")
for line in file:
    data = line.strip().split(",")
    if len(data) >= 2:
        print("Name:", data[0])
        print("Age:", data[1])
    else:
        print(f"Skipping line due to insufficient data: {line.strip()}")
file.close()
# Out:
# Skipping line due to insufficient data: data 60

# %%
file = open("Cleaning steps sample.txt", "r")
content = file.read()
content = content.replace("oldname", "newname")
file.close()
file = open("data.txt", "w")
file.write(content)
file.close()
print("Record updated")
# Out:
# Record updated

# %%
#model handling
import math
print(math.sqrt(25))
print(math.factorial(5))
# Out:
# 5.0
# 120

# %%
import random
otp = random.randint(1000, 9999)
print("OTP:", otp)
# Out:
# OTP: 2146

# %%
def greet():
    print("Welcome to Python")
greet()
# Out:
# Welcome to Python

# %%
from math import sqrt
print(sqrt(64))
# Out:
# 8.0

# %%
import math as m
print(m.pi)
# Out:
# 3.141592653589793

# %%
def add(a, b):
    return a + b
result = add(10, 20)
print("Sum =", result)
# Out:
# Sum = 30

# %%
def hello():
    print("Hello from another folder")
hello()
# Out:
# Hello from another folder

# %%
from datetime import datetime
print(datetime.now())
# Out:
# 2026-05-07 09:38:46.225071

# %%
def add(a, b):
    return a + b
def sub(a, b):
    return a - b
def mul(a, b):
    return a * b
def div(a, b):
    return a / b
print("Addition:", add(10, 5))
print("Subtraction:", sub(10, 5))
print("Multiplication:", mul(10, 5))
print("Division:", div(10, 5))
# Out:
# Addition: 15
# Subtraction: 5
# Multiplication: 50
# Division: 2.0

# %%
def divide(a, b):
    try:
        result = a / b
        print("Result =", result)
    except ZeroDivisionError:
        print("Cannot divide by zero")
divide(10, 0)
# Out:
# Cannot divide by zero
