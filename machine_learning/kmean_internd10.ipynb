# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
data = load_breast_cancer()
X = data.data
feature_names = data.feature_names
print("Dataset shape:", X.shape)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
optimal_k = 2
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
kmeans.fit(X_scaled)
cluster_labels = kmeans.labels_
sil_score = silhouette_score(X_scaled, cluster_labels)
print(f"Silhouette Score for K={optimal_k}: {sil_score:.3f}")
feature_x_index = 0
feature_y_index = 1
plt.figure(figsize=(8,6))
plt.scatter(X_scaled[:, feature_x_index], X_scaled[:, feature_y_index],
            c=cluster_labels, cmap='viridis', s=50, alpha=0.7)
plt.title(f"K-Means Clustering on Breast Cancer Dataset (K={optimal_k})")
plt.xlabel(feature_names[feature_x_index])
plt.ylabel(feature_names[feature_y_index])
plt.colorbar(label='Cluster Label')
plt.show()
# Out:
# Dataset shape: (569, 30)
# Silhouette Score for K=2: 0.345
